# %%
# %matplotlib notebook
import datetime  as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

# %%
style.use('ggplot')
start=dt.datetime(2000,1,1)
end=dt.datetime.today()

# %%
df=web.DataReader('TSLA','yahoo',start,end)
df.head()
# Out:
#              High        Low       Open      Close    Volume  Adj Close
# Date
# 2010-06-29  25.00  17.540001  19.000000  23.889999  18766300  23.889999
# 2010-06-30  30.42  23.299999  25.790001  23.830000  17187100  23.830000
# 2010-07-01  25.92  20.270000  25.000000  21.959999   8218800  21.959999
# 2010-07-02  23.10  18.709999  23.000000  19.200001   5139800  19.200001
# 2010-07-06  20.00  15.830000  20.000000  16.110001   6866900  16.110001

# %%
df['100ma']=df['Adj Close'].rolling(window=100,min_periods=0).mean()
df.dropna(inplace=True)

# %%
ax1=plt.subplot2grid((9,9),(0,0),rowspan=7,colspan=9)    # 6 rows, 1 coloumn and ax1 means subplot #1
ax2=plt.subplot2grid((9,9),(7,0),rowspan=2,colspan=9,sharex=ax1)    # the plot is put on the 5th row and 0th column
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1.plot(df.index,df['Adj Close'])
ax1.plot(df.index,df['100ma'])
ax2.bar(df.index,df['Volume'])
#plt.show()
# Out:
# <BarContainer object of 2116 artists>
